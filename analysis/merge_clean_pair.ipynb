# %% [markdown]
# # Merge - Clean - Pair
#
# results_path = "../results/----/results.csv"
#
# stats_path = "../results/-----/input_change_stats.csv"
#
# ### Semantics clarification
# - `result == sat`  → **Counterexample exists** (property violated)
# - `result == unsat` → **Property proven**
# - `sat True / sat False` column:
#   - `True`  → verification finished successfully
#   - `False` → verification failed / timed out / incomplete
#
# - timeout False -> BnB

# %%
experiment = "one_img_diff_pix_no_seg"

# %%
# MERGE
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt

# Paths
results_path = f"../results/{experiment}/results.csv"
stats_path = f"../results/{experiment}/input_change_stats.csv"
out_path = f"../results/{experiment}/combined_results.csv"

# Load CSVs
df_results = pd.read_csv(results_path)
df_stats = pd.read_csv(stats_path)

# Create instance_id from row number
df_stats.insert(0, "instance_id", range(1,1+len(df_stats)))

df_merged = pd.merge(
    df_stats,
    df_results,
    on="instance_id",
    how="left"
)

# Sort and reset index (optional but safe)
df_merged = df_merged.sort_values("instance_id").reset_index(drop=True)

# Save combined CSV
df_merged.to_csv(out_path, index=False)

print(f"Saved: {out_path}")
# Out:
# Saved: ../results/one_img_diff_pix_no_seg/combined_results.csv

# %%
df = pd.read_csv(out_path)
print(df.shape)
df.head()
# Out:
# (252, 23)
#    instance_id            image                     tag  is_global  \
# 0            1  n01558993_robin  n01558993_robin_global       True
# 1            2  n01558993_robin  n01558993_robin_global       True
# 2            3  n01558993_robin  n01558993_robin_global       True
# 3            4  n01558993_robin  n01558993_robin_global       True
# 4            5  n01558993_robin  n01558993_robin_global       True
#
#    segment_index     eps   k  score  bbox  num_changed  ...  pattern  \
# 0             -1  0.0001  15    NaN   NaN           45  ...   global
# 1             -1  0.0001  30    NaN   NaN           90  ...   global
# 2             -1  0.0001  45    NaN   NaN          135  ...   global
# 3             -1  0.0001  60    NaN   NaN          180  ...   global
# 4             -1  0.0001  75    NaN   NaN          225  ...   global
#
#                 onnx                                             vnnlib  \
# 0  onnx/vgg16-7.onnx  vnnlib/n01558993_robin_global_k15_eps_0.0001.v...
# 1  onnx/vgg16-7.onnx  vnnlib/n01558993_robin_global_k30_eps_0.0001.v...
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
#
#   timeout         result  lb_minus_rhs  domains_visited     bab_time  \
# 0  1200.0  timeout False -2.712000e+11             30.0  1280.064666
# 1  1200.0  timeout False -1.922129e+11             15.0  1441.609780
# 2     NaN            NaN           NaN              NaN          NaN
# 3     NaN            NaN           NaN              NaN          NaN
# 4     NaN            NaN           NaN              NaN          NaN
#
#       all_time  init_unstable
# 0  1286.970044            0.0
# 1  1451.232700            0.0
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
#
# [5 rows x 23 columns]

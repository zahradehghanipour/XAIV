# %%
experiment = "all_pixels_diff_pert_diff_eps"

# %%
# To sort the results.csv by instance_id
CSV_PATH = f"../results/{experiment}/results.csv"

import pandas as pd
df = pd.read_csv(CSV_PATH)
df["instance_id"] = pd.to_numeric(df["instance_id"], errors="coerce")
df_sorted = df.sort_values(by="instance_id", ascending=True)
df_sorted.to_csv(CSV_PATH, index=False)

# %%
# Merge the results.csv and instance(vnnlib property) info
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt

results_path = f"../results/{experiment}/results.csv"
stats_path = f"../results/{experiment}/input_change_stats.csv"
out_path = f"../results/{experiment}/combined_results.csv"

df_results = pd.read_csv(results_path)
df_stats = pd.read_csv(stats_path)

df_stats.insert(0, "instance_id", range(1,1+len(df_stats)))

df_merged = pd.merge(
    df_stats,
    df_results,
    on="instance_id",
    how="left"
)

# Save combined CSV
df_merged.to_csv(out_path, index=False)

print(f"Saved: {out_path}")
# Out:
# Saved: ../results/vggnet16_benchmark2022_segmented_ten_img/combined_results.csv

# %%
CSV_PATH = "../results/vggnet16_benchmark2022_segmented_ten_img/combined_results.csv"

# %%
import pandas as pd

df = pd.read_csv(CSV_PATH)

# Normalize result column
df["result"] = df["result"].astype(str).str.strip()

# Keep only error rows
err_df = df[df["result"] == "error"].copy()

# Pivot table: COUNT of errors per (k, eps)
error_count_matrix = (
    err_df
    .pivot_table(
        index="k",
        columns="eps",
        values="result",
        aggfunc="count",
        fill_value=0
    )
    .sort_index()
)

error_count_matrix
# Out:
# eps    0.0001  0.0002  0.0003  0.0004
# k
# 10          0       1       7       8
# 20          4       7      11      12
# 24          4       7      11      12
# 30          5      10      12      12
# 50          1       4       4       4
# 196         1       3       3       2
# 784         4       0       0       0
# 12544       0       1       1       0
# 25088       1       1       1       0
# 50176       2       0       3       1
